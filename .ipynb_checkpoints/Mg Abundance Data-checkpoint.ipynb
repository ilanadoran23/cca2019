# %%
from solartwins import *
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 15
fig_size[1] = 12
plt.rcParams["figure.figsize"] = fig_size
import scipy.optimize as op

exclusions = ['HIP19911', 'HIP108158', 'HIP109821', 'HIP115577', 'HIP14501', 'HIP28066', 'HIP30476', 
              'HIP33094', 'HIP65708', 'HIP73241', 'HIP74432', 'HIP64150']
for u in exclusions: 
    for i, txt in enumerate(t['star_name']):
        if txt == u:
            t.remove_row(i)

# %%
#BEFORE REMOVING TEMP TRENDS

# %%
x0 = (0.01323581, -0.05390174, -0.01564246) #initial guess
restemp = scipy.optimize.minimize(nlnL, x0, args = (t['age'],t['Mg'],t['Mg_err']))
restemp
# Out:
#       fun: -249.3963317360458
#  hess_inv: array([[ 7.26660240e-07, -3.76071027e-06, -1.15521060e-07],
#        [-3.76071027e-06,  2.28647287e-05,  6.11995268e-07],
#        [-1.15521060e-07,  6.11995268e-07,  2.44742682e-06]])
#       jac: array([6.33239746e-04, 3.43322754e-05, 1.40190125e-03])
#   message: 'Desired error not necessarily achieved due to precision loss.'
#      nfev: 310
#       nit: 10
#      njev: 60
#    status: 2
#   success: False
#         x: array([ 0.00984496, -0.03665832, -0.01235449])

# %%
x0 = (.01,  .05, -.003) #initial guess
som = scipy.optimize.minimize(twodnlnL, x0, args = (t['age'], t['Mg'], t['age_err'], t['Mg_err']))
som
# Out:
#       fun: -249.0533029815324
#  hess_inv: array([[ 6.80709656e-07, -3.54734067e-06,  2.38257727e-06],
#        [-3.54734067e-06,  2.21033523e-05, -6.88996636e-06],
#        [ 2.38257727e-06, -6.88996636e-06,  1.18616537e-02]])
#       jac: array([-1.02348328e-02, -2.49290466e-03,  5.53131104e-05])
#   message: 'Desired error not necessarily achieved due to precision loss.'
#      nfev: 476
#       nit: 17
#      njev: 93
#    status: 2
#   success: False
#         x: array([ 0.0098289 , -0.03650515, -4.43399348])

# %%
#plot of star age vs Mg abundance from above table - before removing temp trends

plt.scatter(t['age'], t['Mg'], c='r') 
plt.xlabel('Age',fontsize='xx-large')
plt.ylabel('Mg/Fe', fontsize='xx-large')
plt.title('Mg Abundance vs. Stellar Age', fontsize='xx-large')

#line of best fit
mb = find_m_b(t['age'], t['Mg'], t['Mg_err'])
for i, txt in enumerate (t['Mg']):
    plot_xs = np.arange(0, 9, .01)
    plt.plot(plot_xs, mb[0] * plot_xs + (mb[1]), color = 'black', linewidth=1)
    
#point labels
for i, txt in enumerate(t['star_name']): 
        plt.annotate(txt, xy=(t['age'][i], t['Mg'][i]), xytext=(-5,5), 
            textcoords='offset points', ha='center', va='bottom')
        
mbtemp= restemp['x']
plot_xs = np.arange(0, 9, .1)
plt.plot(plot_xs, mbtemp[0] * plot_xs + (mbtemp[1]), color = 'blue', linewidth=1)
plt.text(2,.15, '∆ = -0.0284563398933' ,horizontalalignment='right', fontsize=12)
# Out:
# Text(2,0.15,'∆ = -0.0284563398933')

# %%
#AFTER REMOVING TEMP

# %%
#abundance list without temp trends 
x = t['age']
y = t['Mg']
error = t['Mg_err']
mgabundances= residuals(x,y,error)


MgTable = Table([t['star_name'], mgabundances,t['Mg_err'], t['age']], names=('Star', 'Mg Corrected Abundance',
                                                                             'Mg Error','Stellar Age'))

# %%
age = np.array(MgTable['Stellar Age'])
mg = np.array(MgTable['Mg Corrected Abundance'])
err = np.array(MgTable['Mg Error'])
age_err = np.array(t['age_err'])

jackk = find_m_b(age, mg, err)
s = covmatrix(age,mg,err)

# %%
x0 = (0.01, -0.05, -0.01) #initial guess
res = scipy.optimize.minimize(nlnL, x0, args = (age,mg,err))
res
# Out:
#       fun: -249.39633173609508
#  hess_inv: array([[ 6.47673569e-07, -3.33691239e-06, -1.32684563e-07],
#        [-3.33691239e-06,  2.05056139e-05,  7.03156012e-07],
#        [-1.32684563e-07,  7.03156012e-07,  2.30334363e-06]])
#       jac: array([-0.00301933, -0.00102806, -0.00331497])
#   message: 'Desired error not necessarily achieved due to precision loss.'
#      nfev: 345
#       nit: 11
#      njev: 67
#    status: 2
#   success: False
#         x: array([ 0.00135163, -0.00619703, -0.0123545 ])

# %%
x0 = (.01, .03, .07) #initial guess
restem = scipy.optimize.minimize(twodnlnL, x0, args = (age, mg, age_err, err))
restem
# Out:
#       fun: -249.39002422443494
#  hess_inv: array([[ 6.90560319e-07, -3.53282524e-06,  9.98348302e-06],
#        [-3.53282524e-06,  2.14569022e-05, -5.07175984e-05],
#        [ 9.98348302e-06, -5.07175984e-05,  1.63946162e-02]])
#       jac: array([-4.67300415e-04, -3.60488892e-04, -1.90734863e-06])
#   message: 'Desired error not necessarily achieved due to precision loss.'
#      nfev: 387
#       nit: 16
#      njev: 75
#    status: 2
#   success: False
#         x: array([ 1.34583338e-03, -6.16594636e-03, -4.39456626e+00])

# %%
#plot of age and abundance without the temperature trends
plt.scatter(age, mg, c='r') 
plt.xlabel('Age',fontsize='xx-large')
plt.ylabel('Mg/Fe', fontsize='xx-large')
plt.title('Mg Residual Abundance vs. Stellar Age', fontsize='xx-large')

fmb = find_m_b(age, mg, err)
m = fmb[0]
b = fmb[1]

plt.plot(age, m * age + b, color='black') 

for i, txt in enumerate(MgTable['Star']): 
        plt.annotate(txt, xy=(age[i], mg[i]), xytext=(-5,5), 
            textcoords='offset points', ha='center', va='bottom')
        
mb= res['x']
plot_xs = np.arange(0, 9, .1)
plt.plot(plot_xs, mb[0] * plot_xs + (mb[1]), color = 'blue', linewidth=1)
plt.text(2,.1,'∆ = -0.01564246 ',horizontalalignment='right', fontsize=12)
# Out:
# Text(2,0.1,'∆ = -0.01564246 ')

# %%
mb= res['x']
mb2d = som['x']
m = find_m_b(age, mg, err)[0]
b = find_m_b(age, mg, err)[1]
linalgmb = [m, b, 'nan']
categor = ['Slope', 'Intercept' , 'Delta']
nlnLtable= Table([categor, mb, mb2d, linalgmb], names=('Type','Best Fit', '2D Best Fit','Linear Best Fit'))
nlnLtable
# Out:
# <Table length=3>
#    Type          Best Fit            2D Best Fit          Linear Best Fit
#    str9          float64               float64                 str32
# --------- ---------------------- -------------------- -----------------------
#     Slope  0.0013516280174131166  0.00982889765345613  2.0942737962993942e-18
# Intercept -0.0061970302263609405 -0.03650514791247578 -2.7310906426203895e-17
#     Delta  -0.012354502120565939   -4.433993479465214                     nan
