# %%
from solartwins import *
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 15
fig_size[1] = 12
plt.rcParams["figure.figsize"] = fig_size
import scipy.optimize as op

# %%
#plot of star age vs Mg abundance from above table - before removing temp trends

plt.scatter(t['age'], t['Mg'], c='r') 
plt.xlabel('Age',fontsize='xx-large')
plt.ylabel('Mg/Fe', fontsize='xx-large')
plt.title('Mg Abundance vs. Stellar Age', fontsize='xx-large')

#line of best fit
mb = find_m_b(t['age'], t['Mg'], t['Mg_err'])
for i, txt in enumerate (t['Mg']):
    plot_xs = np.arange(0, 9, .01)
    plt.plot(plot_xs, mb[0] * plot_xs + (mb[1]), color = 'black', linewidth=1)
    
#point labels
for i, txt in enumerate(t['star_name']): 
        plt.annotate(txt, xy=(t['age'][i], t['Mg'][i]), xytext=(-5,5), 
            textcoords='offset points', ha='center', va='bottom')
print(mb[0]) #slope value
# Out:
# 0.012892537134757465

# %%
#abundance list without temp trends 
mgabundances = []
for l in (t['star_name']):
    mgabundances.append(residuals(l)[3]) 

MgTable = Table([t['star_name'], mgabundances,t['Mg_err'], t['age']], names=('Star', 'Mg Corrected Abundance',
                                                                             'Mg Error','Stellar Age'))
MgTable
# Out:
# <Table length=79>
#    Star   Mg Corrected Abundance Mg Error Stellar Age
#   bytes9         float64         float64    float64
# --------- ---------------------- -------- -----------
#  HIP10175   -0.01726637854108774    0.007         3.2
# HIP101905  -0.011136756222753813    0.008         1.2
# HIP102040  -0.009509218039743916    0.003         2.4
# HIP102152    0.03920449956305683     0.01         8.6
#  HIP10303    0.01020669915039403    0.005         5.8
# HIP104045  -0.008336349703947983    0.004         4.5
# HIP105184  -0.025125930692797692    0.009         0.7
# HIP108158    0.10047145778470795    0.011         8.1
# HIP108468    0.04423132942526389     0.01         7.0
# HIP109821    0.06801994327970835    0.007         8.9
#       ...                    ...      ...         ...
#  HIP79672 -0.0009559623236952836    0.009         4.0
#  HIP81746    0.04979114998770193    0.006         8.1
#  HIP83276    0.03126746203019533    0.006         7.4
# ...

# %%
#plot of age and abundance without the temperature trends
plt.scatter(MgTable['Stellar Age'], MgTable['Mg Corrected Abundance'], c='r') 
plt.xlabel('Age',fontsize='xx-large')
plt.ylabel('Mg/Fe', fontsize='xx-large')
plt.title('Mg Residual Abundance vs. Stellar Age', fontsize='xx-large')

fmb = find_m_b(MgTable['Stellar Age'], MgTable['Mg Corrected Abundance'], MgTable['Mg Error'])
m = fmb[0]
b = fmb[1]

plt.plot(MgTable['Stellar Age'], m * MgTable['Stellar Age'] + b, color='black') 

for i, txt in enumerate(MgTable['Star']): 
        plt.annotate(txt, xy=(MgTable['Stellar Age'][i], MgTable['Mg Corrected Abundance'][i]), xytext=(-5,5), 
            textcoords='offset points', ha='center', va='bottom')
print(m)
# Out:
# 0.011341497994498333

# %%
HIP10175table = star_table('HIP10175')
abundance = np.array(HIP10175table.columns[1])
error = np.array(HIP10175table.columns[2]) 
temperature = np.array(HIP10175table.columns[3])

jackk = find_m_b(temperature, abundance, error)
s = covmatrix(temperature,abundance,error)
s
# Out:
# matrix([[ 1.63994941e-11, -2.22504882e-08],
#         [-2.22504882e-08,  3.11346864e-05]])

# %%
def variance(param, x, y, error):
    x = np.array(x)
    y = np.array(y)
    error = np.array(error)

    jackk = find_m_b(x, y, error)
    s = covmatrix(x,y,error)

    x0 = [0,0]
    chi = chisquared(x0, x, y, error)
    
    # Hogg 2010 eq 35 : lnL = K - sum [1/2 (ln orthv + V)] - sum [∆/2(orthv + V)]
    m = float(jackk[0])
    b = float(jackk[1])
    K = 0
    #lnL = K - chi/2

    #zi = [z2, z1]
    #z = [x, y]

    theta = np.arctan(jackk[0])
    bcostheta = jackk[1] * np.cos(theta)
    v =(- np.sin(theta), np.cos(theta))
    sumi = np.dot(np.transpose(v), np.dot(s,v).reshape(2,1))
    deltai = np.dot(np.transpose(v), zi) - jackk[1]*np.cos(theta)
    return deltai

# %%
#1/2pi*sqrt(detS) exp(-1/2 * [zi-z]^T Si^-1 [Zi-Z])
#2D uncertainties
zdiff = (np.matrix(zi) - np.matrix(z))
transpz = np.matrix(np.transpose(zdiff)) 
invs = np.matrix(np.linalg.inv(s))

dets = (np.linalg.det(s))

value = np.matrix(np.dot(invs, zdiff)) 

exp = np.dot(value, transpz) 
exp

sig1 = 2*np.pi*np.array(np.sqrt(dets))
sig2 = 1/sig1

#sigma = sig2**[(-1/2)*(exp)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-529591c981a9> in <module>()
#       1 #1/2pi*sqrt(detS) exp(-1/2 * [zi-z]^T Si^-1 [Zi-Z])
#       2 #2D uncertainties
# ----> 3 zdiff = (np.matrix(zi) - np.matrix(z))
#       4 transpz = np.matrix(np.transpose(zdiff))
#       5 invs = np.matrix(np.linalg.inv(s))
#
# NameError: name 'zi' is not defined

# %%
def bestfit(abund, err, age, age_err):   
    # fit
    nll = lambda *args: -lnprob_1sp(*args)
    par0 = np.asarray([0.0, 0.0, 0.0])
    result = op.minimize(nll, par0, args=(abund, err, age, age_err))
    (m, b, lnjitter) = result['x']    
    return m, b, lnjitter

def lnprior(par):
    (m, b, lnjitter) = par
    if (-5. < m < 5.) and (-1. < b < 1.) and (-20. < lnjitter < 1.):
        return 0.0
    return -np.inf

def lnprob_1sp(par, y, dy, x, dx):
    lp = lnprior(par)
    if not np.isfinite(lp):
        return -np.inf
    return lp + twodlike(par, y, dy, x, dx)

# %%
age = np.array(MgTable['Stellar Age'])
mg = np.array(MgTable['Mg Corrected Abundance'])
err = np.array(MgTable['Mg Error'])

jackk = find_m_b(age, mg, err)
s = covmatrix(age,mg,err)

# %%
x0 = [0, -.04] #initial guess
chi = chisquared(x0, age, mg, err)

# %%
variance(x0, age, mg, err)

# %%
bestfit(mg, err, age, age)

# %%
res = scipy.optimize.minimize(chisquared, x0, args=(age, mg, err))
res

# %%
# jitter = some kind of variance / displacement from the line
 
# vee = vˆ = 1/√1 + m2 [−m 1] = [− sin θ cos θ] 

def ortho_displacement(par, ys, xs): #deltai
    # ∆i = vˆT Zi − b cos θ
    (m, b, lnjitter) = par
    disp = np.zeros_like(ys) # array of 0 in the same shape as ys
    
    for i, (y, x) in enumerate(zip(ys, xs)):
        z0 = np.asarray([0.0, b])
        zi = np.asarray([x, y])
        disp[i] = np.dot( vee(par), zi - z0 )
    return disp
    
def ortho_variance(par, dys, dxs):
    # Hogg+2010 eqn 31
    # Σi^2 = vˆT Si vˆ 

    var = np.zeros_like(dys)
    for i, (dy, dx) in enumerate(zip(dys, dxs)):
        cov = np.eye(2)
        cov[0,0] = dx**2
        cov[1,1] = dy**2 #+ jitter**2
        var[i] = np.dot( np.dot(vee(par), cov), vee(par) )
    return var

def twodlike(par, y, dy, x, dx):
    # log(likelihood) considering errors in both x and y
    # Hogg+2010 eqn 31 with jitter
    (m, b, lnjitter) = par
    delta = ortho_displacement(par, y, x)
    sigmasq = ortho_variance(par, dy, dx) + np.exp(2.*lnjitter)
    return -0.5 * np.sum(delta**2/sigmasq + np.log(sigmasq))
    
def lnprior(par):
    (m, b, lnjitter) = par
    if (-5. < m < 5.) and (-1. < b < 1.) and (-20. < lnjitter < 1.):
        return 0.0
    return -np.inf

def lnprob_1sp(par, y, dy, x, dx):
    lp = lnprior(par)
    if not np.isfinite(lp):
        return -np.inf
    return lp + twodlike(par, y, dy, x, dx)

def bestfit_1sp(abund, err, age, age_err):   
    # fit
    nll = lambda *args: -lnprob_1sp(*args)
    par0 = np.asarray([0.0, 0.0, 0.0])
    result = op.minimize(nll, par0, args=(abund, err, age, age_err))
    (m, b, lnjitter) = result['x']    
    return m, b, lnjitter

# %% [markdown]
# run solartwins.py
